# %%
from pycaret.classification import *

import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Load the data

# %%
#df = pd.read_csv("./intermediate_data/.csv", encoding = 'latin')
#df = pd.read_excel("./intermediate_data/.xlsx, engine='openpyxl')
df = pd.read_csv("./intermediate_data/proof_of_concept.csv", encoding = 'latin')

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id_inv  41 non-null     object
#  1   site    41 non-null     object
#  2   xrd1    41 non-null     object
#  3   xrd2    9 non-null      object
#  4   xrd3    2 non-null      object
#  5   Mg      41 non-null     float64
#  6   Al      41 non-null     float64
#  7   Si      41 non-null     float64
#  8   P       41 non-null     float64
#  9   S       41 non-null     float64
#  10  Cl      41 non-null     float64
#  11  K       41 non-null     float64
#  12  Ca      41 non-null     float64
#  13  Sc      41 non-null     float64
#  14  Ti      41 non-null     float64
#  15  V       41 non-null     float64
#  16  Cr      41 non-null     float64
#  17  Mn      41 non-null     float64
#  18  Fe      41 non-null     float64
#  19  Co      41 non-null     float64
#  20  Ni      41 non-null     float64
#  21  Cu      41 non-null     float64
#  22  Zn      41 non-null     float64
#  23  Ga      41 non-null     float64
#  24  Ge      41 non-null     float64
#  25  As      41 non-null     float64
#  26  Se      41 non-null     float64
#  27  Br      41 non-null     float64
#  28  Rb      41 non-null     float64
#  29  Sr      41 non-null     float64
#  30  Y       41 non-null     float64
#  31  Zr      41 non-null     float64
#  32  Nb      41 non-null     float64
#  33  Mo      41 non-null     float64
#  34  Ru      41 non-null     float64
#  35  Pd      41 non-null     float64
#  36  Ag      41 non-null     float64
#  37  Cd      41 non-null     float64
#  38  In      41 non-null     float64
#  39  Sn      41 non-null     float64
#  40  Sb      41 non-null     float64
#  41  Te      41 non-null     float64
#  42  Ba      41 non-null     float64
#  43  Ta      41 non-null     float64
#  44  W       41 non-null     float64
#  45  Au      41 non-null     float64
#  46  Hg      41 non-null     float64
#  47  Tl      41 non-null     float64
#  48  Pb      41 non-null     float64
#  49  Th      41 non-null     float64
# dtypes: float64(45), object(5)
# memory usage: 16.1+ KB

# %% [markdown]
# ### This function load the pre-trained models, perform a prediction on the data and format the output dataframe

# %%
MODEL_NAMES = {
    'model1': 'strunz_classifier',
    'model2': 'classifier'
}

def prediction_function(df, model_key):
    """
    This function performs the following operations:
    * Loads the specified pre-trained model
    * Performs the probability prediction on the dataframe (df).
    * Filters the columns containing the word 'Score' for output formatting purposes
    * Selects the three highest probabilities, sorts them in descending order and presents them in a new column.
    * Finally it returns the dataframe with two new columns of results 'Label' and 'top_3 Probs'.
    """
    
    model = load_model(MODEL_NAMES[model_key])
    pred_prob = predict_model(estimator=model, data=df, raw_score=True)
    
    selected = [] 
    patron = re.compile('.*Score.*', re.IGNORECASE)
    
    for columna in pred_prob.columns:
        if patron.match(columna):
            selected.append(columna)
    
    def select_top_three_cols(row):
        top_three_cols = row.nlargest(3)
        top_three_cols_dict = dict(zip(top_three_cols.index, top_three_cols))
        return top_three_cols_dict
    
    top_three_cols = pred_prob[selected].apply(select_top_three_cols, axis=1)
    pred_prob['top_3_probs'] = top_three_cols
    
    pred_prob = pred_prob.drop(pred_prob[selected].columns, axis=1)
     
    return pred_prob

# %% [markdown]
# ### Using the prediction function with the two models

# %%
# Model 1
preds = prediction_function(df, 'model1')
preds.rename(columns={'prediction_label': 'Predicted Major Class', 'top_3_probs': 'top_3_Major Class'}, inplace=True)
preds = preds.drop(['top_3_Major Class'], axis=1)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Model 2
preds2 = prediction_function(preds, 'model2')
preds2.rename(columns={'prediction_label': 'Predicted Mineral Species', 'top_3_probs': 'top_3_Major Class'}
preds2
# Out:
# Transformation Pipeline and Model Successfully Loaded
#        id_inv                            site         xrd1        xrd2  \
# 0      MP-799                    Can Figueres    Pectolite    Lopezite
# 1      MP-807                    Can Figueres     Petalite         NaN
# 2      MP-790                     Can Sadurni       Quartz         NaN
# 3      MP-792                     Can Sadurni     Hematite         NaN
# 4      MP-793                     Can Sadurni     Fe oxide         NaN
# 5      MP-796                     Can Sadurni     Fe oxide         NaN
# 6      MP-798                     Can Sadurni      Alunite   Variscite
# 7      MP-885                     Can Sadurni    Trolleite      Quartz
# 8     MP-1000                 Cova Cassimanya   Antigorite         NaN
# 9      MP-958                Cova de MontnÃ¡s     Braunite    Cinnabar
# 10     MP-762                  Cueva del Toll    Berlinite     Alunite
# 11     MP-150               Dolmen de la Mota    Lizardite         NaN
# 12     MP-151               Dolmen de la Mota    Lizardite         NaN
# 13     MP-700              La Serreta estr. 5   Perovskite      Spinel
# 14     MP-815                  Marge del Moro      Calcite         NaN
# 15     MP-829                  Roca de L'ivet    Variscite         NaN
# 16     MP-847                  Roca de L'ivet    Variscite         NaN
# 17     MP-184  Sepulcro de MontjuÃc D'altÃ©s    Variscite         NaN
# 18   MRO_1581                Gruta da Marmota  Clinochlore         NaN
# 19   MRO_1836                Gruta da Marmota    Muscovite         NaN
# 20   MRO_1890                Gruta da Marmota    Muscovite         NaN
# 21  MRO_1985A                Gruta da Marmota  Clinochlore         NaN
# 22   MRO_1999                Gruta da Marmota  Clinochlore         NaN
# 23    MRO(N)2                Gruta da Marmota    Muscovite         NaN
# 24    MRO(N)3                Gruta da Marmota    Muscovite         NaN
# 25    MRO(N)5                Gruta da Marmota    Muscovite         NaN
# 26    CLP_131                  Cova das Lapas         Talc         NaN
# 27    CLP_133                  Cova das Lapas  Clinochlore  Phlogopite
# 28    CLP_134                  Cova das Lapas         Talc         NaN
# 29    CLP_136                  Cova das Lapas  Clinochlore  Phlogopite
# 30    CLP_137                  Cova das Lapas  Clinochlore  Phlogopite
# 31    CLP_138                  Cova das Lapas         Talc         NaN
# 32    CLP_139                  Cova das Lapas         Talc         NaN
# 33    CLP_141                  Cova das Lapas         Talc         NaN
# 34    CLP_142                  Cova das Lapas         Talc         NaN
# 35    CLP_143                  Cova das Lapas         Talc         NaN
# 36    CLP_145                  Cova das Lapas         Talc         NaN
# 37    CLP_146                  Cova das Lapas         Talc         NaN
# 38    CLP_148                  Cova das Lapas         Talc         NaN
# 39    CLP_155                  Cova das Lapas         Talc         NaN
# 40    CLP_156                  Cova das Lapas         Talc         NaN
# 28                       Silicates                 Talc
# 29                       Silicates            Muscovite
# 30                       Silicates            Muscovite
# 31                       Silicates                 Talc
# 32                       Silicates                 Talc
# 33                       Silicates          Clinochlore
# 34                       Silicates                 Talc
# 35                       Silicates                 Talc
# 36                       Silicates                 Talc
# 37                       Silicates                 Talc
# 38                       Silicates            Variscite
# 39                       Silicates                 Talc
# 40                       Silicates                 Talc
#
#                                           top_3_probs
# 0   {'prediction_score_Planerite': 0.9533, 'predic...
# 1   {'prediction_score_Aheylite': 0.962, 'predicti...
# 2   {'prediction_score_Illite': 0.6142, 'predictio...
# 3   {'prediction_score_Berlinite': 0.9227, 'predic...
# 4   {'prediction_score_Berlinite': 0.9653, 'predic...
# 5   {'prediction_score_Calcite': 0.9658, 'predicti...
# 6   {'prediction_score_Variscite': 0.9697, 'predic...
# 7   {'prediction_score_Quartz': 0.9637, 'predictio...
# 8   {'prediction_score_Clinochlore': 0.7816, 'pred...
# 9   {'prediction_score_Aragonite': 0.9361, 'predic...
# 10  {'prediction_score_Berlinite': 0.7393, 'predic...
# 11  {'prediction_score_Variscite': 0.636, 'predict...
# 12  {'prediction_score_Clinochlore': 0.7342, 'pred...
# 13  {'prediction_score_Calcite': 0.8906, 'predicti...
# 14  {'prediction_score_Calcite': 0.9658, 'predicti...
# 15  {'prediction_score_Variscite': 0.8719, 'predic...
# 16  {'prediction_score_Variscite': 0.6021, 'predic...
# 17  {'prediction_score_Variscite': 0.9707, 'predic...
# 18  {'prediction_score_Clinochlore': 0.9637, 'pred...
# 19  {'prediction_score_Muscovite': 0.5687, 'predic...
# 20  {'prediction_score_Muscovite': 0.9622, 'predic...
# 21  {'prediction_score_Clinochlore': 0.5361, 'pred...
# 22  {'prediction_score_Chlorite-serpentine': 0.961...
# 23  {'prediction_score_Muscovite': 0.9644, 'predic...
# 24  {'prediction_score_Muscovite': 0.9643, 'predic...
# 25  {'prediction_score_Muscovite': 0.966, 'predict...
# 26  {'prediction_score_Talc': 0.9541, 'prediction_...
# 27  {'prediction_score_Muscovite': 0.9511, 'predic...
# 28  {'prediction_score_Talc': 0.9582, 'prediction_...
# 29  {'prediction_score_Muscovite': 0.9581, 'predic...
# 30  {'prediction_score_Muscovite': 0.9524, 'predic...
# 31  {'prediction_score_Talc': 0.8458, 'prediction_...
# 32  {'prediction_score_Talc': 0.9601, 'prediction_...
# 33  {'prediction_score_Clinochlore': 0.5186, 'pred...
# 34  {'prediction_score_Talc': 0.9164, 'prediction_...
# 35  {'prediction_score_Talc': 0.9556, 'prediction_...
# 36  {'prediction_score_Talc': 0.9507, 'prediction_...
# 37  {'prediction_score_Talc': 0.9398, 'prediction_...
# 38  {'prediction_score_Variscite': 0.8188, 'predic...
# 39  {'prediction_score_Talc': 0.9059, 'prediction_...
# 40  {'prediction_score_Talc': 0.9632, 'prediction_...
#
# [41 rows x 53 columns]

# %% [markdown]
# #### The dataframe with predictions is stored in intermediate_data folder

# %%
preds2.to_csv("./intermediate_data/proof_of_concept_predictions.csv")
