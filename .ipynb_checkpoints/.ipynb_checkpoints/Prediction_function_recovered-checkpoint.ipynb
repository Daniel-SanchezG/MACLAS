# %%
from pycaret.classification import *

import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("./intermediate_DATA/evaluation_DATA/real_world_validation.csv")
#df = pd.read_csv("/home/dsg/META_MODEL_APP/FINAL/intermediate_DATA/MACLAS_preprocessed_dataset.csv")

# %%
df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 54 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21 non-null     int64
#  1   id_inv      21 non-null     object
#  2   site        21 non-null     object
#  3   id_yac      21 non-null     object
#  4   xrd1        21 non-null     object
#  5   xrd2        0 non-null      float64
#  6   xrd3        0 non-null      float64
#  7   DANA8       21 non-null     object
#  8   Strunz      21 non-null     object
#  9   Mg          21 non-null     float64
#  10  Al          21 non-null     float64
#  11  Si          21 non-null     float64
#  12  P           21 non-null     float64
#  13  S           21 non-null     float64
#  14  Cl          21 non-null     float64
#  15  K           21 non-null     float64
#  16  Ca          21 non-null     float64
#  17  Sc          21 non-null     float64
#  18  Ti          21 non-null     float64
#  19  V           21 non-null     float64
#  20  Cr          21 non-null     float64
#  21  Mn          21 non-null     float64
#  22  Fe          21 non-null     float64
#  23  Co          21 non-null     float64
#  24  Ni          21 non-null     float64
#  25  Cu          21 non-null     float64
#  26  Zn          21 non-null     float64
#  27  Ga          21 non-null     float64
#  28  Ge          21 non-null     float64
#  29  As          21 non-null     float64
#  30  Se          21 non-null     float64
#  31  Br          21 non-null     float64
#  32  Rb          21 non-null     float64
#  33  Sr          21 non-null     float64
#  34  Y           21 non-null     float64
#  35  Zr          21 non-null     float64
#  36  Nb          21 non-null     float64
#  37  Mo          21 non-null     float64
#  38  Ru          21 non-null     float64
#  39  Pd          21 non-null     float64
#  40  Ag          21 non-null     float64
#  41  Cd          21 non-null     float64
#  42  In          21 non-null     float64
#  43  Sn          21 non-null     float64
#  44  Sb          21 non-null     float64
#  45  Te          21 non-null     float64
#  46  Ba          21 non-null     float64
#  47  Ta          21 non-null     float64
#  48  W           21 non-null     float64
#  49  Au          21 non-null     float64
#  50  Hg          21 non-null     float64
#  51  Tl          21 non-null     float64
#  52  Pb          21 non-null     float64
#  53  Th          21 non-null     float64
# dtypes: float64(47), int64(1), object(6)
# memory usage: 9.0+ KB

# %%
def prediction_function(df):
    
    """
    This function performs the following operations:
    * Loads the pre-trained model
    * Performs the probability prediction on the dataframe (df).
    * Filters the columns containing the word 'Score' for output formatting purposes
    * Selects the three highest probabilities, sorts them in descending order and presents them in a new column.
    * Finally it returns the dataframe with two new columns of results 'Label' and 'top_3 Probs'.
    
    """
    
    #model= load_model('deployment_XRD_Only_23features_20230707')#'deployment_last_stable_2023-05-06') #load trained model
    #model= load_model('deployment_XRD_Only_20230607')
    model = load_model('deployment_strunz_20230731')
    pred_prob = predict_model(estimator=model, data=df, raw_score=True) # predict on df
    
    #filter columns_____________
    selected = [] 
    patron = re.compile('.*Score.*', re.IGNORECASE)
    
    for columna in pred_prob.columns:
        if patron.match(columna):
            selected.append(columna)
    
    # format output column________
    def select_top_three_cols(row):
        top_three_cols = row.nlargest(3)
        top_three_cols_dict = dict(zip(top_three_cols.index, top_three_cols))
        return top_three_cols_dict
    
    top_three_cols = pred_prob[selected].apply(select_top_three_cols, axis=1)
    pred_prob['top_3_probs'] = top_three_cols
    
    pred_prob = pred_prob.drop(pred_prob[selected].columns, axis=1)
     
    return pred_prob

# %%
preds = prediction_function(df)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
preds.head()
# Out:
#    Unnamed: 0  id_inv                site    id_yac             xrd1  xrd2  \
# 0           0  MP-799  CAN FIGUERES, COVA  CAT01034        Pectolite   NaN
# 1           1  MP-807  CAN FIGUERES, COVA  CAT01034         Petalite   NaN
# 2           2  MP-349   CAN SADURNI, COVA  CAT01005          Sulphur   NaN
# 3           3  MP-788   CAN SADURNI, COVA  CAT01005  Hydroxylapatite   NaN
# 4           4  MP-790   CAN SADURNI, COVA  CAT01005           Quartz   NaN
#
#    xrd3                                              DANA8  \
# 0   NaN                                       Inosilicates
# 1   NaN                                    Phyllosilicates
# 2   NaN                                  no_correspondence
# 3   NaN  Anhydrous Phosphates, etc. Containing Hydroxyl...
# 4   NaN                                  no_correspondence
#
#                            Strunz        Mg         Al         Si          P  \
# 0                       Silicates  0.534567  39.314145  11.827674  26.687470
# 1                       Silicates  0.520289  50.391806   6.222907  26.851988
# 2               no_correspondence  0.402388   5.578874   4.186923   6.533375
# 3  Phosphates,Arsenates,Vanadates  0.548531   8.702245   5.506594  23.838427
# 4                          Oxides  0.650851   4.771027  91.863290   0.930238
#
#            S         Cl         K         Ca        Sc        Ti         V  \
# 0   1.101149   1.310557  0.892404   9.142787  0.005346  0.171760  0.005346
# 1   0.662452   2.396853  0.005203   5.367243  0.005203  0.083369  0.005203
# 2  32.651131  49.715018  0.004024   0.186846  0.004024  0.004024  0.004024
# 3   0.736051   2.312648  0.005485  53.597718  0.005485  0.087092  0.005485
# 4   0.185348   0.584022  0.006509   0.559617  0.006509  0.062275  0.028491
#
#          Cr        Mn        Fe        Co        Ni        Cu        Zn  \
# 0  0.184029  0.005346  1.778445  0.005346  0.005346  6.586235  0.109726
# 1  0.124179  0.005203  0.661017  0.005203  0.005203  6.293889  0.285371
# 2  0.142085  0.004024  0.344636  0.004024  0.004024  0.000402  0.030219
# 3  0.005485  0.282962  0.739527  0.005485  0.005485  3.491826  0.091366
# 4  0.006509  0.006509  0.284256  0.002761  0.006509  0.000651  0.000651
#
#          Ga        Ge        As        Se        Br        Rb        Sr  \
# 0  0.000535  0.000535  0.043309  0.004400  0.000535  0.002127  0.170034
# 1  0.000520  0.000520  0.000520  0.000520  0.000520  0.000520  0.008848
# 2  0.000402  0.000402  0.000402  0.121015  0.000402  0.000402  0.000402
# 3  0.000549  0.000549  0.000549  0.000549  0.000549  0.000549  0.017842
# 4  0.000651  0.000651  0.000651  0.000651  0.000651  0.000914  0.000651
#
#           Y        Zr        Nb        Mo        Ru        Pd        Ag  \
# 0  0.000535  0.003457  0.000535  0.000535  0.000535  0.000535  0.000535
# 1  0.000520  0.000520  0.000520  0.003904  0.000520  0.000520  0.000520
# 2  0.000402  0.000402  0.000402  0.000402  0.000402  0.000402  0.027343
# 3  0.000549  0.000549  0.000549  0.000549  0.000549  0.000549  0.000549
# 4  0.000651  0.001427  0.000651  0.000651  0.000651  0.000651  0.000651
#
#          Cd        In        Sn        Sb        Te        Ba        Ta  \
# 0  0.007561  0.000535  0.000535  0.000535  0.000535  0.091047  0.000535
# 1  0.000520  0.000520  0.010344  0.000520  0.000520  0.072552  0.000520
# 2  0.000402  0.000402  0.000402  0.000402  0.000402  0.000402  0.000402
# 3  0.000549  0.000549  0.000549  0.000549  0.000549  0.000549  0.000549
# 4  0.000651  0.000651  0.000651  0.000651  0.000651  0.026019  0.000651
#
#           W        Au        Hg        Tl       Pb        Th  \
# 0  0.000230  0.000535  0.000535  0.000535  0.00001  0.000535
# 1  0.000326  0.000520  0.000520  0.000520  0.00001  0.000520
# 2  0.000402  0.041920  0.000402  0.000402  0.00001  0.000402
# 3  0.000549  0.000549  0.000549  0.000549  0.00001  0.000549
# 4  0.000651  0.000651  0.000651  0.000651  0.00001  0.000651
#
#                             Label  \
# 0                       Silicates
# 1                       Silicates
# 2  Phosphates,Arsenates,Vanadates
# 3                       Silicates
# 4                          Oxides
#
#                                          top_3_probs
# 0  {'Score_Silicates': 0.9994, 'Score_Carbonates(...
# 1  {'Score_Silicates': 0.9987, 'Score_Phosphates,...
# 2  {'Score_Phosphates,Arsenates,Vanadates': 0.970...
# 3  {'Score_Silicates': 0.4571, 'Score_Carbonates(...
# 4  {'Score_Oxides': 0.9987, 'Score_Silicates': 0....

# %%
preds.to_csv("./intermediate_DATA/evaluation_DATA/predictions_strunz_model.csv")

# %% [markdown]
# **Deleted cases prediction**

# %%
deleted_cases = pd.read_csv('/home/dsg/META_MODEL_APP/EVALUATION/casos_borrados_XRD_only_test.csv', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-94253094b7bf> in <module>
# ----> 1 deleted_cases = pd.read_csv('/home/dsg/META_MODEL_APP/EVALUATION/casos_borrados_XRD_only_test.csv', encoding='latin-1')
#
# ~/META_MODEL_APP/venv/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# ~/META_MODEL_APP/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# ~/META_MODEL_APP/venv/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# ~/META_MODEL_APP/venv/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# ~/META_MODEL_APP/venv/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1991         if kwds.get("compression") is None and encoding:
#    1992             if isinstance(src, str):
# -> 1993                 src = open(src, "rb")
#    1994                 self.handles.append(src)
#    1995
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/dsg/META_MODEL_APP/EVALUATION/casos_borrados_XRD_only_test.csv'

# %%
deleted_cases_pred = prediction_function(deleted_cases)
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
deleted_cases_pred.to_csv("./intermediate_DATA/evaluation_DATA/predictions_strunz_model.csv")
