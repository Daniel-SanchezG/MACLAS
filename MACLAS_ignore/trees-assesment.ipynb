# %%
import pandas as pd
import numpy as np
from pycaret.classification import * # machine learning tools
import matplotlib.pyplot as plt # visualization
import seaborn as sns
from ipywidgets import widgets # Interactive functions
import graphviz 
import lightgbm as lgb
import pylab

# %%
from pycaret import oop.py
# Out:
#   File "/tmp/ipykernel_93367/3969944116.py", line 1
#     from pycaret import oop.py
#                            ^
# SyntaxError: invalid syntax

# %%
model = load_model('tunedclassifier')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
#lgb.plot_tree(model)
kwargs = {"format": 'png', "directory":'./MACLAS_final/tables', 'filename':'tree1'}
viz = lgb.create_tree_digraph(model.booster_,tree_index=0, show_info=['split_gain','internal_count','internal_value', 'data_percentage'], format='png', directory='./MACLAS_final/', filename='tree')
#pylab.savefig('tree.png')
#viz.view()
viz

# %%
model.get_params()
# Out:
# {'memory': FastMemory(location=/tmp/joblib),
#  'steps': [('label_encoding',
#    TransformerWrapperWithInverse(transformer=LabelEncoder())),
#   ('numerical_imputer',
#    TransformerWrapper(include=['Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'K', 'Ca', 'Sc',
#                                'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn',
#                                'Ga', 'Ge', 'As', 'Se', 'Br', 'Rb', 'Sr', 'Y', 'Zr',
#                                'Nb', 'Mo', 'Ru', ...],
#                       transformer=SimpleImputer())),
#   ('categorical_imputer',
#    TransformerWrapper(include=[],
#                       transformer=SimpleImputer(strategy='most_frequent'))),
#   ('trained_model',
#    LGBMClassifier(bagging_fraction=0.9, bagging_freq=3, class_weight='balanced',
#                   feature_fraction=0.8, min_child_samples=91, min_split_gain=0,
#                   n_estimators=170, num_leaves=20, random_state=123,
#                   reg_alpha=0.0001, reg_lambda=1))],
# ...

# %%
tree_info = model.booster_.trees_to_dataframe()
tree_info.tree_index.nunique()
# Out:
# 3060

# %%
graph = graphviz.Source(viz, format="png") 
graph
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/.local/lib/python3.8/site-packages/graphviz/jupyter_integration.py in _repr_mimebundle_(self, include, exclude, **_)
#      96         include = set(include) if include is not None else {self._jupyter_mimetype}
#      97         include -= set(exclude or [])
# ---> 98         return {mimetype: getattr(self, method_name)()
#      99                 for mimetype, method_name in MIME_TYPES.items()
#     100                 if mimetype in include}
#
# ~/.local/lib/python3.8/site-packages/graphviz/jupyter_integration.py in <dictcomp>(.0)
# ...
